# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Евгений, привет!**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если это неприемлемо, то дай мне знать и мы перейдем на «вы».
#
# Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их отработки проект не будет принят. При проверке я обращаю внимание не только на код, но и на интерпретацию и анализ результатов, а также соответствие данных техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно делаешь, что не убираешь описание задачи. Это поможет быстро вспомнить, о чем проект, если ты к нему вернешься спустя какое-то время.
#
# Данный блок можно расширить при помощи плана работы и описания данных. Посмотреть подробнее про вступительный блок можно в разделе "Полезные инструкции в учебе" блока "Оформление проекта".
#
#
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %%
import pandas as pd

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
import matplotlib.pyplot as plt
data.hist(figsize=(30, 40));
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Предупреждения перед графиками можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку matplotlib.pyplot as plt
# 2. В конец кода добавить `;`
# </div>

# %% [markdown]
# **После просмотра общих данных и  построения гистограмм можно увидеть, что тип данных в некоторых столбцах необходимо будет изменить, а так же есть аномалии или выбросы, с которыми нужно будет разобраться**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Хорошая вводная часть.
#
# Рекомендую создать универсальную функцию, которая будет принимать на вход датафрейм, а на выходе она будет выводить всего нужные характеристики, например, head, describe, info, дубликаты и т.п.
# </div>

# %% [markdown]
# ### Выполните предобработку данных

# %% [markdown]
# **Подсчитаем количество пропущеных значений в таблице**

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Также, помимо абсолютных значений мы можем посмотреть долю пропусков, и на основании этого принять решение о удалении, замене либо игнорировании пропусков, например: `pd.DataFrame(round(df.isna().mean()*100,1)).style.background_gradient('coolwarm')`
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Благодарю за совет, добавил и теперь буду пользоваться.
# </div>

# %%
pd.DataFrame(round(data.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_347a1_row0_col0,#T_347a1_row1_col0,#T_347a1_row2_col0,#T_347a1_row3_col0,#T_347a1_row4_col0,#T_347a1_row8_col0,#T_347a1_row10_col0,#T_347a1_row11_col0,#T_347a1_row14_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_347a1_row5_col0{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_347a1_row6_col0{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_347a1_row7_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_347a1_row9_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_347a1_row12_col0{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_347a1_row13_col0{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_347a1_row15_col0,#T_347a1_row16_col0,#T_347a1_row17_col0,#T_347a1_row19_col0{
# ...

# %% [markdown]
# **После подсчета количества пропущенных значений в таблице, можно увидеть:**

# %% [markdown]
# ***- Пропуски есть в столбцах, которые заполняются автомотически, например,  расстояние до ближайшего аэропорта, расстояние до центра, количество водоемов и парков, а так же расстояние до них. Такие пропуски могли появиться из-за не правильного или не точного выбора адреса продавцом, либо это техническая проблема на сайте.***
#
# *Пропуски в этих данных мы не сможем заполнить, поэтому оставим их без изменений.*

# %% [markdown]
# ***- Пропуски в столбцах с высотой потолков, количеством этажей в здании, жилой площадью, аппартаменты, площадью кухни, количеством балконов и названием населенного пункта были пропущены пользователями. Возможно они не знают этих данных или посчитали эту информацию не важной и пропустили, а может намеренно скрыли данные.***
#
# *Пропуски мы можем заполнить в столбце количества балконов, скорей всего продавец не указал количество, потому что у него нет балконов, а так же в столбце апартаменты мы видим большое количество пропусков, скорей всего продавец пропустил этот пункт, потому что у него не аппартаменты. В описнии данных сказано, что столбец 'is_apartment' имеет булев тип, а по факту мы видим тип object. Заполним даннные пропуски на False и потом изменим тип данных. Столбец с количеством этажей в зднии имеет не большое количество пропусков, заполнить их нулевым значением нельзя, оставить пропуски можно, но при дальнейшей работе это никак не поможет, заменим пропуски на этаж, который продавец указал в объявлении и потом изменим тип данных.*

# %% [markdown]
# ***- Пропуски в столбце количества дней размещения объявлений, возможно появились из-за того, что обьявление снято в тот же день. Можно проверить эту теорию, если объявление снято в тот же день значит количество дней должно равняться нулю.Проверим минимальное значение в столбце.***

# %%
print(data['days_exposition'].min())
# Out:
# 1.0

# %% [markdown]
# *Минимальное значение равно 1, посмотрим какие объявления и сколько таких имеет показатель 1*

# %%
data.loc[data['days_exposition'] < 2]
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 1632            19   4000000.0        49.9  2019-05-01T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1632             2.5           9.0         25.0      1          NaN  ...
#
#       kitchen_area  balcony    locality_name  airports_nearest  \
# 1632          10.0      NaN  Санкт-Петербург           13567.0
#
#      cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 1632             14384.0               1.0           20.0               1.0
#
#       ponds_nearest  days_exposition
# 1632          681.0              1.0
#
# [1 rows x 22 columns]

# %% [markdown]
# *Всего одно объявление, значит наша теория верна, оставим пропуски без изменения, чтобы в дальнейшем это не повлияло на исследование.*

# %% [markdown]
# **Заполняем пропущенные значения в данных**

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно, люди не заполняют "не выгодные" для продажи квартиры характеристики.
# </div>

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Все верно, либо это апартаменты, либо нет. Булев тип подходит лучше всего.
# </div>

# %%
# data['days_exposition'] = data['days_exposition'].fillna(0)

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Дни экспозиции я бы вообще не заполнял, тк признак далее используется, а твое заполнение по сути обязует тебя отбрасывать записи при подсчете показателей
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Оставил пропуски
# </div>

# %%
# data['floors_total'] = data['floors_total'].fillna(data['floor'])

# %%
data = data.dropna(subset=['floors_total'])

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Доля пропусков здесь менее 5% и мы вполне можем их удалить.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Удалил данные строки из таблицы
# </div>

# %%
for t in data['locality_name'].unique():
    data.loc[(data['locality_name'] == t) & (data['ceiling_height'].isna()), 'ceiling_height'] = \
    data.loc[(data['locality_name'] == t), 'ceiling_height'].median()
# Out:
# /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
# ...

# %%
data = data.dropna(subset=['ceiling_height'])

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Высоту можно заполнить медианой с учетом группировки по локации или расстоянию до центра в км, логично что в большинстве случаев потолки в исторической застройке выше. Либо же как вариант заполнить медианой.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Высоту потолков заполнил медианой по локации, столбца с расстоянием до центра в км у нас пока нет. Оставшиеся пропуски удалил
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# **Подсчитаем количество пропущеных значений в таблице после заполнения**

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1841
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2195
# balcony                     0
# locality_name              14
# airports_nearest         5411
# cityCenters_nearest      5388
# parks_around3000         5387
# parks_nearest           15422
# ponds_around3000         5387
# ponds_nearest           14415
# days_exposition          3145
# dtype: int64

# %% [markdown]
# **Изменим тип данных в столбцах `last_price`, `floors_total`, `balcony`, `days_exposition` на `int`, а `is_apartment` на `bool`**
#
# *Изменить тип в столбцах на целочисленный тип необходимо, потому что эти столбцы имеют только целые числа*

# %%
data = data.astype({'last_price': int, 'floors_total': int, 'balcony': int, 'days_exposition': int, 'is_apartment': bool}, errors='ignore')

# %% [markdown]
# **Изменим тип данных в столбце `first_day_exposition`**

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y.%m.%dT%H:%M:%S')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 При чтении файла можно указать параметр `parse_dates: parse_dates=['date']`. Тогда пандас автоматически переведет список столбцов в даты. Пример можно посмотреть [здесь](https://newtechaudit.ru/gruzi-daty-krasivo/).
# </div>

# %% [markdown]
# **Проверим, что тип данных изменился**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23459 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23459 non-null  int64
#  1   last_price            23459 non-null  int64
#  2   total_area            23459 non-null  float64
#  3   first_day_exposition  23459 non-null  datetime64[ns]
#  4   rooms                 23459 non-null  int64
#  5   ceiling_height        23459 non-null  float64
#  6   floors_total          23459 non-null  int64
#  7   living_area           21618 non-null  float64
#  8   floor                 23459 non-null  int64
#  9   is_apartment          23459 non-null  bool
#  10  studio                23459 non-null  bool
#  11  open_plan             23459 non-null  bool
#  12  kitchen_area          21264 non-null  float64
#  13  balcony               23459 non-null  int64
#  14  locality_name         23445 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# С типом данных согласен.
# </div>

# %% [markdown]
# **Посмотрим есть ли явные дубликаты в таблице.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Дубликатов нет**

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# При подготовке я смотрел есть ли дубликаты в таблице, но не стал оставлять, в задании этого не было
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# А этого в заданиях и не будет, это основа.
# </div>

# %% [markdown]
# **Посмотрим уникальные значения в столбце с названиями населенного пункта**

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %% [markdown]
# **Заменим букву `ё` на `е`, а так же `городской поселок` на `поселок городского типа` и `поселок станции` на `поселок при железнодорожной станции`**

# %%
data['locality_name'] = (
    data['locality_name']
    .str.replace('ё', 'е')
    .replace('городской поселок', 'поселок городского типа', regex=True)
    .replace('поселок станции', 'поселок при железнодорожной станции', regex=True)
)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично! Можно еще применить такой подход:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Буду иметь ввиду
# </div>

# %% [markdown]
# **Проверим, что названия изменились правильно**

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалево',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'деревня Агалатово', 'деревня Батово', 'деревня Бегуницы',
#        'деревня Белогорка', 'деревня Большая Вруда',
#        'деревня Большая Пустомержа', 'деревня Большие Колпаны',
#        'деревня Бор', 'деревня Борисова Грива', 'деревня Ваганово',
#        'деревня Вартемяги', 'деревня Вахнова Кара', 'деревня Гарболово',
# ...

# %% [markdown]
# **Посмотрим уникальные значения в столбце с высотой потолков**

# %%
data['ceiling_height'].sort_values().unique()
# Out:
# array([  1.   ,   1.2  ,   1.75 ,   2.   ,   2.2  ,   2.25 ,   2.3  ,
#          2.34 ,   2.4  ,   2.45 ,   2.46 ,   2.47 ,   2.48 ,   2.49 ,
#          2.5  ,   2.51 ,   2.515,   2.52 ,   2.525,   2.53 ,   2.54 ,
#          2.55 ,   2.555,   2.56 ,   2.56 ,   2.57 ,   2.575,   2.58 ,
#          2.59 ,   2.6  ,   2.6  ,   2.61 ,   2.615,   2.62 ,   2.625,
#          2.63 ,   2.64 ,   2.65 ,   2.65 ,   2.66 ,   2.67 ,   2.675,
#          2.68 ,   2.69 ,   2.7  ,   2.71 ,   2.72 ,   2.725,   2.73 ,
#          2.74 ,   2.75 ,   2.76 ,   2.77 ,   2.78 ,   2.79 ,   2.8  ,
#          2.81 ,   2.82 ,   2.83 ,   2.84 ,   2.85 ,   2.86 ,   2.87 ,
#          2.88 ,   2.89 ,   2.9  ,   2.91 ,   2.92 ,   2.93 ,   2.94 ,
#          2.95 ,   2.96 ,   2.97 ,   2.98 ,   2.99 ,   3.   ,   3.01 ,
#          3.02 ,   3.03 ,   3.04 ,   3.05 ,   3.06 ,   3.07 ,   3.08 ,
#          3.09 ,   3.1  ,   3.11 ,   3.12 ,   3.13 ,   3.14 ,   3.15 ,
# ...

# %% [markdown]
# **В столбце есть значения, которые не похожи на высоту потолков в помещениях. Выведем все значения с высотой потолков от 1 до 2 метров и больше 14 метров по возврастанию столбца `ceiling_height`**

# %%
data.loc[data['ceiling_height'].isin([1, 1.2, 1.75, 2, 14, 20, 22.6, 24, 25, 26, 27, 27.5, 32, 100])].sort_values(by='ceiling_height')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22590            16     6000000       55.00           2018-10-31      2
# 5712              5     1500000       42.80           2017-08-14      2
# 16934             5     4100000       40.00           2017-10-17      1
# 22960            17     2300000       53.60           2018-10-18      2
# 16446             6    12300000       88.30           2019-03-12      3
# 16884             0     1500000       33.00           2018-10-03      1
# 5850              9     1650000       35.50           2018-05-29      1
# 19098             7     2700000       56.00           2018-02-04      3
# 4212              1     2120000       35.43           2017-12-18      1
# 20520             9     3600000       38.00           2018-07-05      1
# 2572              4     2400000       62.00           2018-12-27      3
# 552              11     2999000       33.50           2017-03-30      1
# ...

# %% [markdown]
# **В таблице мы видим, что 24, 25, 26 и 27 метров несколько объявлений, скорей всего это ошибка, изменим их на 2.4, 2.5, 2.6 и 2.7 метра. Объявления с высотой от 1 до 1,75, а так же от 14 до 100 метров удалим из таблицы.**

# %%
data['ceiling_height'] = (
    data['ceiling_height'].replace(25, 2.5, regex=True)
    .replace(26, 2.6, regex=True).replace(27, 2.7, regex=True)
    .replace(24, 2.4, regex=True)
)

# %%
data = data.loc[(data['ceiling_height'] < 14) & (data['ceiling_height'] > 1.75)]

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Обрати внимание, что здесь мы теряем почти 40% данных. Этого мы себе позволить не можем. Стоит проводить фильтрацию аккуратно. Удалять более 10% данных мы не можем. Если выбросы - более 10%, то это уже не выбросы, а наоборот один из трендов.
#
# Данные нам необходимо вернуть.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Долго не мог понять про какие 40% идет речь, а потом посмотрел, что там пропусков почти на 40%.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
# Код ревьюера
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23449 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23449 non-null  int64
#  1   last_price            23449 non-null  int64
#  2   total_area            23449 non-null  float64
#  3   first_day_exposition  23449 non-null  datetime64[ns]
#  4   rooms                 23449 non-null  int64
#  5   ceiling_height        23449 non-null  float64
#  6   floors_total          23449 non-null  int64
#  7   living_area           21608 non-null  float64
#  8   floor                 23449 non-null  int64
#  9   is_apartment          23449 non-null  bool
#  10  studio                23449 non-null  bool
#  11  open_plan             23449 non-null  bool
#  12  kitchen_area          21254 non-null  float64
#  13  balcony               23449 non-null  int64
#  14  locality_name         23435 non-null  object
# ...

# %% [markdown]
# **Проверим, что значения в столбце с высотой потолков изменились**

# %%
data['ceiling_height'].sort_values().unique()
# Out:
# array([ 2.   ,  2.2  ,  2.25 ,  2.3  ,  2.34 ,  2.4  ,  2.45 ,  2.46 ,
#         2.47 ,  2.48 ,  2.49 ,  2.5  ,  2.51 ,  2.515,  2.52 ,  2.525,
#         2.53 ,  2.54 ,  2.55 ,  2.555,  2.56 ,  2.56 ,  2.57 ,  2.575,
#         2.58 ,  2.59 ,  2.6  ,  2.6  ,  2.61 ,  2.615,  2.62 ,  2.625,
#         2.63 ,  2.64 ,  2.65 ,  2.65 ,  2.66 ,  2.67 ,  2.675,  2.68 ,
#         2.69 ,  2.7  ,  2.71 ,  2.72 ,  2.725,  2.73 ,  2.74 ,  2.75 ,
#         2.76 ,  2.77 ,  2.78 ,  2.79 ,  2.8  ,  2.81 ,  2.82 ,  2.83 ,
#         2.84 ,  2.85 ,  2.86 ,  2.87 ,  2.88 ,  2.89 ,  2.9  ,  2.91 ,
#         2.92 ,  2.93 ,  2.94 ,  2.95 ,  2.96 ,  2.97 ,  2.98 ,  2.99 ,
#         3.   ,  3.01 ,  3.02 ,  3.03 ,  3.04 ,  3.05 ,  3.06 ,  3.07 ,
#         3.08 ,  3.09 ,  3.1  ,  3.11 ,  3.12 ,  3.13 ,  3.14 ,  3.15 ,
#         3.16 ,  3.17 ,  3.18 ,  3.2  ,  3.21 ,  3.22 ,  3.23 ,  3.24 ,
#         3.25 ,  3.26 ,  3.27 ,  3.28 ,  3.29 ,  3.3  ,  3.31 ,  3.32 ,
# ...

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Замечания:
#
# * Отсутствует проверка явных дубликатов в датасете, а это основа предобработки данных.
#
#
# * Отсутствует промежуточный вывод о проделанной работе в разделе.
#
#
# Дополни, пожалуйста.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Проверка явных дубликатов сделана выше, промежуточный вывод написал ниже
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# **Проведя предобработку данных мы увидели, что есть данные, которые по каким-то причинам не заполняются автоматически, а так же есть данные, которые продавцы заполняют не корректно или не заполяют вовсе. Разобрались с пропусками в данных, изменили не корректные данные и их тип.**

# %% [markdown]
# ### Добавьте в таблицу новые столбцы

# %% [markdown]
# **Добавим в таблицу новый столбец с ценой одного квадратного метра `price_of_one_square_meter`**

# %%
data['price_of_one_square_meter'] = round(data['last_price']/data['total_area'], 2)

# %% [markdown]
# **Добавим в таблицу новый столбец с днем недели, когда была выставлена публикация `day_of_the_week`**

# %%
data['day_of_the_week'] = data['first_day_exposition'].dt.weekday

# %% [markdown]
# **Добавим в таблицу новый столбец месяц `month`, в который была выставлена публикация**

# %%
data['month'] = data['first_day_exposition'].dt.month

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# На будущее: часто датафреймы содержат данные за разные годы. Чтобы корректно обработать месяцы и не объединить их из разных годов, можно рассмотреть такой метод `astype('datetime64[M]')`. При использовании этого метода не придется ссылаться на `pd.DatetimeIndex`.
#
# Рекомендую ознакомиться с этими материалами:
#
# [Работа с датами в Python]( https://pythobyte.com/how-to-work-with-dates-and-times-in-python-0a176355/)
#
# [Извлечение часов, минут и секунд из numpy datetime64](https://stackoverflow.com/questions/70901855/get-hour-and-minutes-and-seconds-from-numpy-datetime64)
#
# Попробуй использовать этот метод, когда агализируешь динамику по неделям, месяцам или годам.
#
# Пример применения:
#
#
# `df['first_day_exposition'].dt.date # конвертация в формат даты
# df['first_day_exposition'].astype('datetime64[M]')`
#
# Если даты в датафрейме из разных годов, то после преобразования месяцы будут отображаться как первый день каждого месяца, например '2019-05-01'.
#
# </div>

# %% [markdown]
# **Добавим в таблицу новый столбец год `year`, в который была выставлена публикация**

# %%
data['year'] = data['first_day_exposition'].dt.year

# %% [markdown]
# **Добавим в таблицу новый столбец тип этажа квартиры `type_floor`, который покажет `первый`, `последний`, `другой`**

# %%
def type_floor(row):
    floor = row['floor']
    floors_total = row['floors_total']
    if floor == 1:
        return 'первый'
    if 1 < floor == floors_total:
        return 'последний'
    return 'другой'

# %%
data['type_floor'] = data.apply(type_floor, axis=1)

# %% [markdown]
# **Добавим в таблицу новый столбец `city_centers_km`, который покажет расстояние до центра города в киллометрах**

# %%
data['city_centers_km'] = round(data['cityCenters_nearest']/1000).round()

# %% [markdown]
# **Посмотрим на изменения в нашей таблице и проверим правильность заполнения новых столбцов**

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0           2.700            16         51.0      8         False  ...
# 1           2.615            11         18.6      1         False  ...
# 2           2.700             5         34.3      4         False  ...
# 3           2.700            14          NaN      9         False  ...
# 4           3.030            14         32.0     13         False  ...
#
#    parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# ...

# %% [markdown]
# ** **

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Отлично! Можем приступать к исследовательскому анализу.
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# **Построим гистограммы для каждого из этих параметров:**
#
# ***Общая площадь;
# жилая площадь;
# площадь кухни;
# цена объекта;
# количество комнат;
# высота потолков;
# тип этажа квартиры («первый», «последний», «другой»);
# общее количество этажей в доме;
# расстояние до центра города в метрах;
# расстояние до ближайшего парка***

# %% [markdown]
# **Общая площадь:**

# %%
(
    data.plot(kind='hist', y='total_area',
              title='Распределение общей площади недвижимости',
              label='ggg',
              bins= 30, figsize=(5, 10),grid=True, legend=False)
)
plt.xlabel('Общая площадь')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Обрати, пожалуйста, внимание на оформление графиков в проекте. Важно, чтобы у каждого графика было название, а оси были четко подписаны. Пожалуйста, пройдись по всем графикам и убедись в их корректном оформлении.
#
# Помни, график — это инструмент общения с заказчиком. Он должен быть ясным, лаконичным и информативным.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Изменил
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Евгений, чтобы график был по-настоящему информативным и понятным, важно также чётко подписать оси. Это помогает лучше понять представленные данные.
#
# В текущем графике название оси Y есть, и это хорошо, но оно должно точно описывать, что измеряется — например, 'Частота' или 'Количество объектов'. Также стоит добавить подпись к оси X, чтобы было понятно, к какой величине относятся значения — например, 'Общая площадь, м²'.
#
# Кроме того, важно, чтобы сам график имел название, объясняющее его содержание. Вместо 'total_area' можно использовать что-то вроде 'Распределение общей площади объектов недвижимости'.
#
# Прошу тебя пройтись по всем графикам в проекте.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Добавил название и подписал оси во всех графиках
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %%
data.loc[data['total_area'] < 20]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 716               5     1500000       17.00           2017-06-07      0
# 4542             12     3300000       18.00           2018-11-07      1
# 5855              3      945750       19.50           2017-09-18      0
# 6084              6      770000       18.00           2017-10-16      1
# 8454              7     2250000       19.00           2019-03-12      0
# 8729              9     2200000       18.40           2018-08-20      1
# 8755              1     1350000       18.80           2017-11-22      0
# 8886             10     2450000       15.50           2018-08-22      0
# 9157              0     3400000       17.60           2018-03-18      1
# 9412              5     2100000       16.00           2017-12-10      0
# 9817              8     2190000       19.00           2018-10-12      0
# 10208             3     1900000       17.00           2018-08-14      1
# ...

# %%
data.loc[data['total_area'] > 400]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 660               3    49950000      483.90           2017-10-04      7
# 3117             19   140000000      631.00           2019-03-30      7
# 3676             12    28789000      441.98           2019-01-23      4
# 4237              1    50000000      517.00           2017-10-14      7
# 5358             20    65000000      590.00           2019-02-14     15
# 5893              3   230000000      500.00           2017-05-31      6
# 6221              8    34000000      470.30           2018-01-14      4
# 6621             20    99000000      488.00           2017-04-09      5
# 8018             20    84000000      507.00           2015-12-17      5
# 9826              1    43185328      494.10           2017-05-12      1
# 12401            20    91500000      495.00           2017-06-19      7
# 12859            20   140000000      631.20           2019-04-09      7
# ...

# %% [markdown]
# **После построения гистораммы и дополнительных таблиц с данными видно, что основная часть объявлений имеет площадь объектов до 100 метров квадратных, минимальное значение не равно 0, значит не корректных данных тут нет, объевления площадью больше 300 квадратных метров тоже выглядят правдоподобно, цена соответствует большой квадратуре.**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно, с большей площадью меньше предложений. Объекты выше 90-100 кв. м - это более дорогой сегмент.
# </div>

# %% [markdown]
# **Жилая площадь:**

# %%
(
    data.plot(kind='hist', y='living_area',
              title='Распределение жилой площади недвижимости',
              bins= 30, figsize=(5, 10),grid=True, legend=False)
)
plt.xlabel('Жилая площадь')
plt.ylabel('Частота')
plt.show()

# %%
data.loc[data['living_area'] < 10]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 114               5     4000000       21.40           2019-02-07      1
# 680              14     7200000       43.00           2017-10-31      1
# 1326              8     8100000       52.00           2017-01-29      2
# 2309             10     4200000       62.40           2017-06-15      2
# 3242              7     4440000       41.00           2017-07-02      1
# 4100             17     5300000       34.80           2017-06-19      1
# 4542             12     3300000       18.00           2018-11-07      1
# 7312              8     3400000       27.00           2018-02-21      2
# 8325              9     4800000       52.00           2017-10-25      2
# 13915            20     6350000       52.00           2018-02-06      2
# 15833            20     4600000       33.00           2017-01-01      1
# 16431            13     3799000       31.00           2018-04-12      1
# ...

# %%
data.loc[data['living_area'] > 200]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 660               3    49950000       483.9           2017-10-04      7
# 793              20   135000000       310.0           2018-05-22      4
# 866               5    25000000       363.0           2017-12-23     14
# 1085             16    75000000       323.0           2017-07-10      5
# 1494             10    65000000       364.0           2018-11-27      7
# 2580              6    30900000       338.6           2017-10-16      7
# 4237              1    50000000       517.0           2017-10-14      7
# 5358             20    65000000       590.0           2019-02-14     15
# 6221              8    34000000       470.3           2018-01-14      4
# 6621             20    99000000       488.0           2017-04-09      5
# 7857             11   150000000       230.0           2017-10-25      8
# 8018             20    84000000       507.0           2015-12-17      5
# ...

# %% [markdown]
# **После построения гистораммы и дополнительных таблиц с данными видно, что есть некорректные данные, например, общая площадь 62,4 метра квадратных, а жилай 8,4 и таких объявлений достаточно много, возможно продавцы не правильно понимают какие данные нужно вносить или не знают точных данных.**

# %% [markdown]
# **Площадь кухни:**

# %%
(
    data.plot(kind='hist', y='kitchen_area',
              title='Распределение площади кухни', bins= 30,
              figsize=(5, 10),grid=True, legend=False)
)
plt.xlabel('Площадь кухни')
plt.ylabel('Частота')
plt.show()

# %%
data['kitchen_area'].min()
# Out:
# 1.3

# %%
data['kitchen_area'].max()
# Out:
# 112.0

# %%
data.loc[data['kitchen_area'] > 80]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 2489              9    12500000       255.0           2017-04-21      3
# 5358             20    65000000       590.0           2019-02-14     15
# 10867             1    56844500       177.9           2015-01-15      3
# 16239             5    82400000       181.1           2017-05-24      3
# 16797             9    65850000       146.0           2017-07-14      2
# 19540             8   420000000       900.0           2017-12-06     12
# 20215             2    85000000       249.7           2018-02-01      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 2489              2.7             2        153.9      2         False  ...
# 5358              3.5             6        409.0      3         False  ...
# 10867             2.7             6         87.2      5          True  ...
# 16239             3.9             9         58.2      4         False  ...
# ...

# %% [markdown]
# **После построения гистораммы и дополнительных данных видно, что данные записаны лучше, чем жилая площадь, минимальное значение не равно 0, а вот объявление с максимальным значением выглядит странно. Помещение 900 квадратных метров, кухня 112 квадратных метров и все это на 25 этаже за 420 млн.**

# %% [markdown]
# **Цена объекта:**

# %%
(
    data.plot(kind='hist', y='last_price',
              title='Цена объектов недвижимости', bins= 30,
              figsize=(5, 10),grid=True, legend=False)
)
plt.xlabel('Цена, млн.')
plt.ylabel('Количество объектов')
plt.show()

# %%
data.loc[data['last_price'] < 500000]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5698              7      450000        42.0           2017-07-31      2
# 8793              7       12190       109.0           2019-03-20      2
# 10782             3      490000        29.1           2016-05-05      1
# 16032             8      480000        32.0           2019-01-06      1
# 16219            14      450000        38.5           2018-07-11      2
# 17456             7      430000        30.4           2019-04-22      1
# 21912             0      470000        37.0           2018-02-18      1
# 23484            11      470000        44.5           2018-07-02      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 5698            2.615             1         23.0      1         False  ...
# 8793            2.750            25         32.0     25         False  ...
# 10782           2.500             5         17.0      5         False  ...
# ...

# %%
data.loc[data['last_price'] > 130000000]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 793              20   135000000       310.0           2018-05-22      4
# 1026             20   155000000       310.0           2018-10-12      5
# 1436             19   330000000       190.0           2018-04-04      3
# 2243              9   130278280       304.0           2015-07-24      5
# 2536             16   159984000       242.4           2015-08-27      4
# 3117             19   140000000       631.0           2019-03-30      7
# 5893              3   230000000       500.0           2017-05-31      6
# 7674             20   131000000       380.0           2016-09-23      5
# 7857             11   150000000       230.0           2017-10-25      8
# 8900             13   190870000       268.0           2016-03-25      3
# 12674            16   140000000       241.0           2015-07-24      5
# 12859            20   140000000       631.2           2019-04-09      7
# ...

# %% [markdown]
# **После построения гистораммы и дополнительных таблиц видно, что минимальная цена 12190, скорей всего это ошибка и нужно удалить данную строку, цена на дорогие объекты с большой площадью выгледят корректно.**

# %%
data = data.loc[data['last_price'] > 400000]

# %% [markdown]
# **Количество комнат:**

# %%
(
    data.plot(kind='hist', y='rooms',
              title='Распределение количества комнат недвижимости ',
              bins= 30, figsize=(5, 10),grid=True, legend=False)
)
plt.xlabel('Количество комнат')
plt.ylabel('Количество объектов')
plt.show()

# %%
data.loc[data['rooms'] < 1]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 144               1     2450000       27.00           2017-03-30      0
# 349               4     2320000       25.00           2017-09-27      0
# 440               8     2480000       27.11           2018-03-12      0
# 508               0     3375000       34.40           2017-03-28      0
# 608               2     1850000       25.00           2019-02-20      0
# ...             ...         ...         ...                  ...    ...
# 23210             7     3200000       26.00           2017-09-01      0
# 23442             0     2500000       27.70           2017-09-28      0
# 23554            15     3350000       26.00           2018-09-07      0
# 23592            10     1450000       29.00           2017-11-11      0
# 23637             8     2350000       26.00           2018-06-26      0
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
data.loc[data['rooms'] > 10]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 648               3    17500000       183.7           2018-07-01     11
# 866               5    25000000       363.0           2017-12-23     14
# 5358             20    65000000       590.0           2019-02-14     15
# 9688              8    33000000       194.1           2017-02-07     11
# 14498             6    32250000       374.6           2018-06-09     19
# 18848             6    28500000       270.0           2015-03-02     16
# 19540             8   420000000       900.0           2017-12-06     12
# 20829             6    28659000       245.4           2016-03-31     14
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 648              3.40             7        138.8      7         False  ...
# 866              3.16             5        222.0      4         False  ...
# 5358             3.50             6        409.0      3         False  ...
# ...

# %% [markdown]
# **После построения гистораммы и дополнительной таблицы видно, что есть объекты недвижимости с количеством комнат 0, скорей всего это квартиры студии, либо объекты свободной планировки, так же есть объекты с количеством комнат более 10. Основная часть объектов это 1,2 и 3 комнатные квартиры.**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍Верно, однокомнатные популярней по ряду причин: цена(доступней для одиноких людей, а также людям в гражданском браке), рентабельность(покупка с целью продать дороже, а так же сдача в наём для приезжих, студентов и т.д), наследство.
# </div>

# %% [markdown]
# **Высота потолков:**

# %%
(
    data.plot(kind='hist', y='ceiling_height',
              title='Распределение высоты потолков', bins= 30,
              figsize=(5, 10),grid=True, legend=False)
)
plt.xlabel('Высота потолков')
plt.ylabel('Количество объектов')
plt.show()

# %% [markdown]
# **После построения гистораммы видно, что основная часть недвижимости имеет высоту потолков от 2,5 до 3,2 метров, есть объявления с двухэтажными квартирами(дуплекс), аномалии по данному столбцу мы убрали ранее.**

# %% [markdown]
# **Тип этажа квартиры («первый», «последний», «другой»):**

# %%
data['type_floor'].hist(bins= 30, figsize=(5, 10))
plt.xlabel('Тип этажа')
plt.ylabel('Количество объектов')
plt.show()

# %% [markdown]
# **После построения гистораммы видно, что квартир в продаже на первом и последней этаже практически одинакомое колличество, но большую часть занимает группа `другой`.**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Да, чаще всего продают не последний и не первый этажи - такие этажи могут быть проблемными (заглядывают прохожие, холодно, жарко, протекает крыша и т.д.)
#
# Также это связано с этажностью строительства. Первый и последний этажи - это лишь по одному этажу, а группа "другой" включает в себя все этажи, кроме первого и последнего. Для 3-этажных домов мы бы увидели равномерное распределение, но строительство заметно выше, чем 3 этажа.
# </div>

# %% [markdown]
# **Общее количество этажей в доме:**

# %%
(
    data.plot(kind='hist', y='floors_total',
              title='Распределение по общему количеству этажей в доме',
              bins= 30, figsize=(5, 10),grid=True, legend=False)
)
plt.xlabel('Количество этажей')
plt.ylabel('Количество объектов')
plt.show()

# %%
data.loc[data['floors_total'] < 2]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3076             20     2000000        80.0           2018-01-03      3
# 4379              5     5300000        58.5           2017-11-15      2
# 5300              5     2990000        60.0           2018-11-15      3
# 5698              7      450000        42.0           2017-07-31      2
# 5787             16     9000000        88.0           2018-08-06      3
# 7962              4      550000        46.2           2018-04-20      3
# 8335             10     2700000        80.0           2018-07-07      3
# 8388             20     3550000        48.2           2019-03-30      3
# 9517              4     1200000        39.4           2018-01-08      2
# 10817             6      790000        50.6           2017-11-29      3
# 11641             6     3685000        44.7           2018-07-05      1
# 11746            10     1070000        38.8           2018-06-20      2
# ...

# %%
data.loc[data['floors_total'] > 30]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 397              15     5990000        54.0           2018-03-22      2
# 871              14     7777777        75.0           2017-11-16      2
# 1060             10     5200000        50.0           2015-11-06      2
# 1697             11     3550000        28.0           2018-02-08      1
# 1917             13    10150000        74.0           2017-11-17      2
# 2253             12     3800000        45.5           2018-06-28      2
# 2966              9     4300000        37.0           2017-08-08      1
# 4855             12     5500000        50.0           2017-06-22      1
# 5749             20     3590000        25.0           2017-08-30      0
# 5807             17     8150000        80.0           2019-01-09      2
# 5808             12     4590000        43.0           2018-10-19      1
# 7236             10     4599000        42.0           2019-01-10      1
# ...

# %% [markdown]
# **После построения гистораммы и дополнительной таблицы видно, что минимальное значение имеет 1 этаж, так как мы заполняли пропуски этажами, которые указаны в объялении продавцами, а вот объявления с 60 этажным домом и 52 этажным выгледят подозрительно, скорей всего это ошибка, удалим эти объявления.**

# %%
data = data.loc[data['floors_total'] < 37]

# %% [markdown]
# **Расстояние до центра города в метрах:**

# %%
(
    data.plot(kind='hist', y='cityCenters_nearest',
              title='Распределение расстояния до центра города', bins= 30,
              figsize=(5, 10),grid=True, legend=False)
)
plt.xlabel('Расстояние в метрах')
plt.ylabel('Количество объектов')
plt.show()

# %%
data['cityCenters_nearest'].min()
# Out:
# 181.0

# %%
data.loc[data['cityCenters_nearest'] > 60000]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 577               7     4000000        59.0           2017-07-23      3
# 2974             13     3200000        46.3           2018-03-31      2
# 5218             15     3650000        53.8           2018-09-24      3
# 5340             19     3600000        50.6           2019-03-19      2
# 9640              8     4200000        51.4           2014-12-10      2
# 16569            13     3200000        52.8           2017-06-20      2
# 18884            15     3600000        57.6           2019-02-08      3
# 20746             1     3300000        43.5           2016-02-16      2
# 23123             0     1800000        32.0           2018-07-17      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 577              2.50             5         37.0      1         False  ...
# 2974             2.50             3         29.2      2         False  ...
# ...

# %% [markdown]
# **После построения гистораммы и дополнительной таблицы видно, что минимальное значение имеет значение 181, а максимальное больше 60000 метров, так как мы рассматриваем Ленинградскую область, в этом нет ничего странного. Основная часть приходится на расстояние 11-12 тысяч метров от центра.**

# %% [markdown]
# **Расстояние до ближайшего парка:**

# %%
(
    data.plot(kind='hist', y='parks_nearest',
              title='Распределение расстояния до парка', bins= 30, figsize=(5, 10),
              grid=True, legend=False)
)
plt.xlabel('Расстояние в метрах')
plt.ylabel('Количество объектов')
plt.show()

# %%
data.loc[data['parks_nearest'] < 500]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 2                10     5196000       56.00           2015-08-20      2
# 3                 0    64900000      159.00           2015-07-24      3
# 4                 2    10000000      100.00           2018-06-19      2
# 10                5     5050000       39.60           2017-11-16      1
# ...             ...         ...         ...                  ...    ...
# 23686             8     3300000       31.00           2017-04-29      1
# 23689            13     3550000       35.30           2018-02-28      1
# 23690             3     5500000       52.00           2018-07-19      2
# 23693             9     4600000       62.40           2016-08-05      3
# 23697            13    11475000       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
data.loc[data['parks_nearest'] > 2500]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1590              3     7500000        70.0           2017-07-11      2
# 1804             20    13800000       114.0           2018-10-29      3
# 1860             19     3500000        45.0           2016-12-05      2
# 2659              9    19150000       104.9           2017-08-28      3
# 3865             20    11900000        91.2           2018-10-04      3
# 5923              6     6698000        60.0           2018-07-18      2
# 6625              7     5000000        36.6           2018-02-07      1
# 7316              5     7100000        74.5           2016-04-19      3
# 7855             16     5200000        44.9           2019-03-04      2
# 10959             9     3000000        31.1           2017-03-21      1
# 18327            18     6100000        54.5           2018-06-24      2
# 18685            11     6700000        65.6           2017-05-02      3
# ...

# %% [markdown]
# **После построения гистораммы и дополнительных таблиц видно, что большая часть объявлений находится менее, чем в 1000 метров от парков, гораздо меньше объявлений находятся более чем 2500 метров.**

# %% [markdown]
# ***Изучите, как быстро продавались квартиры (столбец `days_exposition`)***

# %%
data['days_exposition'].mean()
# Out:
# 181.07239952718678

# %%
data['days_exposition'].median()
# Out:
# 95.0

# %%
data.boxplot('days_exposition')
# Out:
# <AxesSubplot:>

# %%
data.boxplot('days_exposition')
plt.ylim(1200,1600)
# Out:
# (1200.0, 1600.0)

# %%
data.boxplot('days_exposition')
plt.ylim(0,600)
# Out:
# (0.0, 600.0)

# %%
data['days_exposition'].describe()
# Out:
# count    20304.000000
# mean       181.072400
# std        220.040023
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# **После нахождения среднегозначения в 181 день и медианы в 95 дней, можно сказать, что данные сильно отличаются, потому что есть объявления с большим сроком размещения. На диаграмме размаха можно увидеть, что значение больше 510 дней можно считать долгими, но чтобы понять какие объявления можно считать быстрыми, посмотрим на список характерных значений. На нем мы видим, что объявления до 45 дней можно считать быстрими, а разница между стандартным отклонением и средним арифметическим отличается. Это еще раз подтверждает, что в данных есть серьезные аномалии. Объявления свыше 1200 дней можно считать необычно долгими.**

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Немного не так, чтобы ответить на вопрос "Какие продажи можно считать быстрыми, а какие — необычно долгими?" лучше посмотреть на распределение данные с помощью boxplot() или describe(). Ориентироваться лучше на Q1.  А также, нам необходимо отфильтровать заглушку, которая искажает результаты.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Изменил вывод
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ***Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта***

# %% [markdown]
# **Общая стоимость к общей площади:**

# %%
data.plot(x='total_area', y='last_price', style='o',alpha=0.3, figsize=(5, 7), grid=True)
# Out:
# <AxesSubplot:xlabel='total_area'>

# %% [markdown]
# *После построения графика видим, что есть закономерность при увеличении площади, стоимость растет. Посмотрим коэффициент Пирсона, чтобы точно понять, что вывод верный.*

# %%
data['total_area'].corr(data['last_price'])
# Out:
# 0.653719271570606

# %% [markdown]
# *Коэффициент Пирсона равен 0,71, а это значит он положительный и взаимосвязь есть.*

# %% [markdown]
# **Общая стоимость к жилой площади:**

# %%
data.plot(x='living_area', y='last_price', style='o',alpha=0.3, figsize=(5, 10), grid=True)
# Out:
# <AxesSubplot:xlabel='living_area'>

# %% [markdown]
# *После построения графика таж же видим, что есть закономерность при увеличении площади, стоимость растет. Но мы помним, что с данными были проблемы. Утверждать, что именно жилая площадь влияет на цену не стоит.*

# %% [markdown]
# **Общая стоимость к площади кухни:**

# %%
data.plot(x='kitchen_area', y='last_price', style='o',alpha=0.3, figsize=(5, 10), grid=True)
# Out:
# <AxesSubplot:xlabel='kitchen_area'>

# %% [markdown]
# *В данном графике тоже видим закономерность, что при увеличении площади цена вырастает, но график не такой как с общей площадью и для лучшего понимания можно найти корреляцию.*

# %%
data['kitchen_area'].corr(data['last_price'])
# Out:
# 0.5206110984967053

# %% [markdown]
# *Корреляция в 0.53 говорит о наличии связи, однако не слишком сильной.*

# %% [markdown]
# **Общая стоимость к количеству комнат:**

# %%
data.plot(x='rooms', y='last_price', style='o', figsize=(5, 10), grid=True)
# Out:
# <AxesSubplot:xlabel='rooms'>

# %% [markdown]
# *В данном графике четко видно, что при увеличении количества комнат цена растет.*

# %% [markdown]
# **Общая стоимость к этажу, на котором расположена квартира (первый, последний, другой):**

# %%
data.plot(x='type_floor', y='last_price', style='o',alpha=0.2, figsize=(30, 10), grid=True)
# Out:
# <AxesSubplot:xlabel='type_floor'>

# %% [markdown]
# *В графике видим, что данный фактор не сильно влияет на общую стоимость.*

# %% [markdown]
# **Общая стоимость к дате размещения (день недели, месяц, год):**

# %%
data.plot(x='day_of_the_week', y='last_price', style='o', figsize=(30, 10), grid=True)
data.plot(x='month', y='last_price', style='o', figsize=(30, 10), grid=True)
data.plot(x='year', y='last_price', style='o', figsize=(30, 10), grid=True)
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# *В графиках видим, что в 2017 году цена выше по сравнению с 2016 и 2018, таж же видим, что в феврале и июле цены выше в сравнение с другими месяцами, день недели не сильно влияет, на выходных заметно меньше показатели.*

# %% [markdown]
# **В итоге при построении графиков мы увидели, что цена напрямую зависит от количества комнат и площади помещения, так же в 2017 и 2018 году показатели лучше.**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верная интерпретация полученных данных
# </div>

# %% [markdown]
# ***Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений***

# %% [markdown]
# **Построим сводную таблицу с количеством объявлений и средней ценой одного квадратного метра. Для этого добавим новую переменную `data_sort`, которая в дальнейшем станет нашей сводной таблицей. Для начала сформируем сводную таблицу, в которой мы посчитаем количество объявлений в каждом населенном пункте. Далее добавим в таблицу столбец `average_price_one_meter`, в котором посчитаем среднее значение квадратного метра. Переименнуем столбец `price_of_one_square_meter` на `number_of_ads` для красоты и оставим в нашей сводной таблице только 10 населённых пунктах с наибольшим числом объявлений**

# %%
data_sort = data.pivot_table(index='locality_name', values='price_of_one_square_meter', aggfunc='count')
data_sort = data_sort.rename(columns={'price_of_one_square_meter': 'number_of_ads'})
data_sort['average_price_one_meter'] = data.pivot_table(index='locality_name', values='price_of_one_square_meter', aggfunc='mean')
data_sort = data_sort.sort_values(by='number_of_ads', ascending=False).head(10)
data_sort
# Out:
#                    number_of_ads  average_price_one_meter
# locality_name
# Санкт-Петербург            15641            114852.387157
# поселок Мурино               552             85629.568641
# поселок Шушары               439             78551.344647
# Всеволожск                   398             68654.473970
# Пушкин                       369            103125.819377
# Колпино                      338             75424.579112
# поселок Парголово            327             90175.913089
# Гатчина                      307             68746.146515
# деревня Кудрово              299             92473.547559
# Выборг                       237             58141.909325

# %% [markdown]
# **Из получившейся сводной таблице видно, что большее количество объявлений, конечно, в Санкт-Петербурге и средняя цена за квадратный метр в нем самая высокая 114,8 тысяч, а в Выборге средняя цена самая низкая, всего 58,1 тысяч.**

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Здесь стоит еще раз взглянуть на результат после возвращения данных.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Изменил вывод
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Верно
# </div>

# %% [markdown]
# ***Выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите их среднюю стоимость на разном удалении от центра***

# %%
(
    data.query('locality_name == "Санкт-Петербург"')
    .pivot_table(index='city_centers_km', values='last_price', aggfunc='mean')
    .plot(style='o-',alpha=0.5, figsize=(5, 7), grid=True)   
)
# Out:
# <AxesSubplot:xlabel='city_centers_km'>

# %% [markdown]
# **Из получившегося графика видно, что средняя стоимость снижается при удалении от центра, но так же есть волны с повышением цены с 3 до 6 км, затем цена снова опускается и большой всплеск на 27 км. Возможно это престижные районы с дорогой недвижимостью или новые районы в городе с новостройками и развитой инфоструктурой**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верно
# </div>

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# В данном проекте мы рассмотрели архив объявлений о прадаже квартир в Санкт-Петербурге и населенных пунктах вблизи него.
#
# Выясняли:
# - Есть пропуски в данных, которые подгружаются автоматически, возможно есть какая-то ошибка и с ней нужно разобраться.
# - Есть пропуски в данных, которые клиенты должны заполнять и эти данные важны для исследования, например, точное название населенного пунка, количество этажей в доме, высота потолков. Стоит обратить внимание на данные пункты, уточнить почему они не корректно заполняются или пропускаются вовсе.
# Провели исследовательский анализ:
# - Узнали, что объявления сроком до 45 дней можно считать быстрыми, а больше 510 дней долгими, но есть и необычно долгие объявления от 1200 дней.
# - Узнали, что на стоимость жилья на прямую зависит общая площадь, количество комнат, а так же этаж на котором она расположена.
# - Узнали, что в 2017 году цены на жилью были ваше, а самые популярные 1 и 2 комнатные квартиры.
# - Выделили группу населенных пунктов с самым большим количеством объявлений, возглавил этот список Санкт-Петербург, а так же узнали среднюю цену одного квадратного метра в нем, она равна 114852. В городе Пушкин цена чуть ниже 103125 и самая низкая в этом списке в Выборге 58141.
# - Узнали, что средняя цена в Санкт-Петербурге снижается в зависимости от расстояния от центра, но есть районы, в которых цена выше не зависимо от расстояния.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Для большей наглядности для заказчика предлагаю структурировать итоговые выводы, выделяя ключевые аспекты работы. В финальном разделе стоит максимально детализировать и обогатить информацией с конкретными цифрами все найденные закономерности и особенности в данных в ходе исследования.
#
# Давай сделаем обзорную часть более развернутой, чтобы подчеркнуть качество проведенной работы и предоставить заказчику полное понимание проведенного анализа.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Изменил вывод
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# Евгений, замечательная работа, ты мыслишь нестандартно, это отличный навык, который у тебя уже есть, ты последователен и вдумчив. Твою работу очень интересно читать и проверять.  Я оставил несколько обязательных поправок для тебя и после этого буду готов сразу принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
# Евгений, спасибо, что прислал работу на повторное ревью. По проекту у нас осталось только оформление графиков, после этого проект может быть принят.

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.3</b>
#
# 👋
#
# Евгений, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [x]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [x]  Найдены пропущенные значения.
# - [x]  Пропущенные значения заполнены там, где это возможно.
# - [x]  Объяснено, какие пропущенные значения обнаружены.
# - [x]  В каждом столбце установлен корректный тип данных.
# - [x]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [x]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [x]  Обработаны редкие и выбивающиеся значения (аномалии).
# - [x]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [x]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [x]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [x]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [x]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [x]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [x]  На каждом этапе сделаны промежуточные выводы.
# - [x]  В конце проекта сделан общий вывод.
